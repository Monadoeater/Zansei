# %% [markdown]
# <a href="https://colab.research.google.com/github/Monadoeater/Zansei/blob/main/c_pia_de_atividade_pr_tica_individual_ra2_b_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Atenção: Regras para a solução da atividade.**
# 1. Para participar desta avaliação o aluno precisa estar presente em sala, alunos que não respoderem a chamada terão a avaliação zerada.
# 2. copie este caderno para a sua conta, criando as células de texto e código que forem necessárias após o enunciado de cada questão;
# 3. não apague os enunciados;
# 4. responda as questões na ordem em que elas se apresentam neste caderno;
# 5. pode, e deve, consultar todo e qualquer recurso disponível na internet. Mas, não pode consultar nenhum outro ser humano.
# 6. Poste no AVA (Canvas) o link para a sua resposta. Pode ser um link para a solução no Google Colab, ou um link para o caderno com suas respostas no Github.
#
# A violação de qualquer uma destas regras provoca a anulação da avaliação.
#
# Qualquer link que não possa ser executado a partir do link postado irá zerar a avaliação.
#
# Qualquer link que leve a uma pasta, arquivo comprimido, ou qualquer outro destino que não seja um caderno executável com as suas repostas provocará a anulação da questão. Teste usando outro navegador que não esteja logado nas suas contas.
#
# Qualquer link que não possa ser aberto, irá zerar a avaliação.
#
# Qualquer comunicação com outro ser humano irá zerar a avaliação.

# %% [markdown]
# # Questão 1 (vale 6 pontos)
# Considerando as funções listadas a seguir faça: **(a)** o gráfico das três funções; **(b)** o passo a passo algébrico, em latex, para encontrar o ângulo de inclinação da reta tangente no ponto $x=5$ para cada das funções:
#
# 1. $
# f(x) = (x^2 - 4)(x^3 - 8x-1)
# $
# 2. $
# f(x) = \sin(x^3)\cos(x)
# $
# 3.$
# f(x) = x^2e^{-2x}\ln(x)
# $
#
# Se você usar o sympy, terá que fazer com que ele imprima todos os passos necessários para resolver cada uma das operações, regras, ou tabelas que aplicar para resolver o problema.
#
# Em todas as questões você pode usar apenas os métodos, regras, técnicas e algoritmos que utilizamos na nossa disciplina, em sala, ou no material de apoio.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return (x**2 - 4) * (x**3 - 8*x - 1)

x = np.linspace(0, 10, 100)
y = f(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('$f(x) = (x^2 - 4)(x^3 - 8x - 1)$')
plt.grid(True)
plt.show()

# %% [markdown]
# Função 1:
#
# Calcular a derivada da função f(x)
#
# $f(x) = (x^2 - 4)(x^3 - 8x - 1)$
#
# $f'(x) = (2x)(x^3 - 8x - 1) + (x^2 - 4)(3x^2 - 8)$
#
# Simplificar a expressão:
#
# $f'(x) = 2x^4 - 16x^2 - 2x^2 + 16x + 3x^4 - 8x^3 - 3x^2 + 8x$
#
# $f'(x) = 5x^4 - 11x^3 - 19x^2 + 24x$
#
# Substituir x=5 na derivada
#
# $f'(5) = 5(5^4) - 11(5^3) - 19(5^2) + 24(5)$

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

x = np.linspace(-10, 10, 400)
y = np.sin(x**3) * np.cos(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('$f(x) = sin(x^3) * cos(x)$')
plt.grid(True)
plt.show()

# %% [markdown]
# Função 2:
#
# Definir a função:
#
# $f(x) = \sin(x^3) \cos(x)$
#
# Calcular a derivada:
#
# $f'(x) = \frac{d}{dx}(\sin(x^3) \cos(x))$
#
# Usando regra do produto:
#
# $f'(x) = \sin(x^3) \frac{d}{dx}(\cos(x)) + \cos(x) \frac{d}{dx}(\sin(x^3))$
#
# Diferenciando os termos:
#
# $f'(x) = \sin(x^3) (-\sin(x)) + \cos(x) \cos(x^3) \frac{d}{dx}(x^3)$
#
# Derivada de $x^3$
#
# $f'(x) = \sin(x^3) (-\sin(x)) + \cos(x) \cos(x^3) (3x^2)$
#
# Simplificando a expressão
#
# $f'(x) = -\sin(x) \sin(x^3) + 3x^2 \cos(x) \cos(x^3)$
#
# Substituindo x=5 na derivada:
#
# $f'(5) = -\sin(5) \sin(5^3) + 3(5^2) \cos(5) \cos(5^3)$

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.1, 10, 400)
y = x**2 * np.exp(-2*x) * np.log(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('f(x) = x^2 * e^(-2x) * ln(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# Função 3:
#
# Definir a função:
#
# $f(x) = x^2 \cdot e^{-2x} \cdot \ln(x)$
#
# Calcular a derivada:
#
# $f'(x) = \frac{d}{dx}(x^2 \cdot e^{-2x} \cdot \ln(x))$
#
# Regra do produto e regra da cadeia:
#
# $f'(x) = \frac{d}{dx}(x^2) \cdot e^{-2x} \cdot \ln(x) + x^2 \cdot \frac{d}{dx}(e^{-2x}) \cdot \ln(x) + x^2 \cdot e^{-2x} \cdot \frac{d}{dx}(\ln(x))$
#
# Diferenciando cada termo:
#
# $f'(x) = 2x \cdot e^{-2x} \cdot \ln(x) + x^2 \cdot (-2) \cdot e^{-2x} \cdot \ln(x) + x^2 \cdot e^{-2x} \cdot \frac{1}{x}$
#
# Simplificando a expressão:
#
# $f'(x) = 2x \cdot e^{-2x} \cdot \ln(x) - 2x^2 \cdot e^{-2x} \cdot \ln(x) + \frac{x}{e^{2x}}$
#
# Substituindo x=5
#
# $f'(5) = 2(5) \cdot e^{-2(5)} \cdot \ln(5) - 2(5)^2 \cdot e^{-2(5)} \cdot \ln(5) + \frac{5}{e^{2(5)}}$

# %% [markdown]
# # Questão 2 (vale 2 pontos)
# Uma empresa espacial está tentando descobrir o ponto mínimo da órbita de um satélite cuja função orbital é dada por:
# $$f(x)=7\sin(x)-2\cos(x)$$
#
# Encontre o primeiro ponto de mínimo no intervalo $-10<=x<=10$.
#
# Como sempre, você pode usar qualquer ferramenta disponível na internet para lhe auxiliar a resolver este problema. Lembre-se, contudo, que o sympy é uma boa alternativa.
#
# Em todas as questões você pode usar apenas os métodos, regras, técnicas e algoritmos que utilizamos na nossa disciplina, em sala, ou no material de apoio. Lembrem-se estamos limitados as bibliotecas sympy, numpy e matplotlib.
#
# Para resolver esta questão você precisará de, no minimo, 4 casas decimais de precisão depois da vírgula.

# %%
import sympy as sp

# Variável x
x = sp.Symbol('x')

# Função orbital
f = 7*sp.sin(x) - 2*sp.cos(x)

# Derivada da função
f_prime = sp.diff(f, x)

# Igualando a derivada a zero e resolvendo a equação
pontos_criticos = sp.solve(f_prime, x)

# Pontos críticos dentro do intervalo -10 <= x <= 10
pontos_criticos_validos = [ponto.evalf() for ponto in pontos_criticos if -10 <= ponto.evalf() <= 10]

# Mínimo valor da função dentro do intervalo
valor_minimo = min([f.subs(x, ponto) for ponto in pontos_criticos_validos])

# Ponto de mínimo correspondente ao mínimo valor
ponto_minimo = [(ponto, f.subs(x, ponto).evalf()) for ponto in pontos_criticos_validos if f.subs(x, ponto) == valor_minimo]

ponto_minimo
# Out:
# [(-1.29249666778979, -7.28010988928052)]

# %% [markdown]
# # Questão 3 (vale 2 pontos)
# Considerando a função $f(x,y) = \sin(xy) + \cos(x+2y)$, no intervalo $0\leq x\leq 5 \space\space e \space\space 0\leq y\leq 5$ trace, usando o plotly o gráfico desta função e marque os pontos de máximo e mínimo neste intevalo.
#
# Lembre-se o sympy é sempre uma opção e você pode usar qualquer técnica, algoritmo, regra, ou tabela, que tenha sido usada na matéria. E que precisa de apenas uma casa decimal de precisão. Uma dica importante para a solução deste problema é a função **np.unravel_index**

# %%
import numpy as np
import plotly.graph_objects as go

# Função
def f(x, y):
    return np.sin(x * y) + np.cos(x + 2 * y)

# Grade de pontos no intervalo desejado
x_vals = np.linspace(0, 5, 100)
y_vals = np.linspace(0, 5, 100)
X, Y = np.meshgrid(x_vals, y_vals)
Z = f(X, Y)

# índices dos pontos de máximo e mínimo
max_indices = np.unravel_index(np.argmax(Z), Z.shape)
min_indices = np.unravel_index(np.argmin(Z), Z.shape)

# Plotando o gráfico
fig = go.Figure(data=[go.Surface(x=X, y=Y, z=Z)])
fig.update_layout(
    title="f(x, y) = sin(xy) + cos(x + 2y)",
    scene=dict(
        xaxis_title="x",
        yaxis_title="y",
        zaxis_title="f(x, y)"
    )
)

# Pontos de máximo e mínimo
fig.add_trace(go.Scatter3d(
    x=[X[max_indices]],
    y=[Y[max_indices]],
    z=[Z[max_indices]],
    mode='markers',
    marker=dict(
        size=5,
        color='red',
        symbol='circle'
    ),
    name='Ponto Máximo'
))

fig.add_trace(go.Scatter3d(
    x=[X[min_indices]],
    y=[Y[min_indices]],
    z=[Z[min_indices]],
    mode='markers',
    marker=dict(
        size=5,
        color='cyan',
        symbol='circle'
    ),
    name='Ponto Mínimo'
))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fe86afd6-e546-44b7-ab04-16b327d66ad0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe86afd6-e546-44b7-ab04-16b327d66ad0")) {                    Plotly.newPlot(                        "fe86afd6-e546-44b7-ab04-16b327d66ad0",                        [{"x":[[0.0,0.050505050505050504,0.10101010101010101,0.15151515151515152,0.20202020202020202,0.25252525252525254,0.30303030303030304,0.35353535353535354,0.40404040404040403,0.45454545454545453,0.5050505050505051,0.5555555555555556,0.6060606060606061,0.6565656565656566,0.7070707070707071,0.7575757575757576,0.8080808080808081,0.8585858585858586,0.9090909090909091,0.9595959595959